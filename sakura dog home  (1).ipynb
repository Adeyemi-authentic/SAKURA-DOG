# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dogs=pd.read_excel(r"C:\Users\USER\OneDrive\Documents\dog_breeds.xlsx")
dogs
# Out:
#                                  Breed Country of Origin  \
# 0                   Labrador Retriever            Canada
# 1                      German Shepherd           Germany
# 2                              Bulldog           England
# 3                               Poodle            France
# 4                               Beagle           England
# 5                            Chihuahua            Mexico
# 6                                Boxer           Germany
# 7                     Golden Retriever          Scotland
# 8                                  Pug             China
# 9                           Rottweiler           Germany
# 10                      Siberian Husky            Russia
# 11                           Dachshund           Germany
# 12                            Shih Tzu             China
# 13                        Bichon Frise            France
# 14                 Australian Shepherd         Australia
# ...

# %%
pd.set_option('display.max.rows',117)

# %%
dogs.shape
# Out:
# (117, 8)

# %%
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       2 non-null      int64
#  1   Values  2 non-null      int64
# dtypes: int64(2)
# memory usage: 164.0 bytes

# %%
dogs.drop_duplicates(subset='Breed')
# Out:
#                                  Breed Country of Origin  \
# 0                   Labrador Retriever            Canada
# 1                      German Shepherd           Germany
# 2                              Bulldog           England
# 3                               Poodle            France
# 4                               Beagle           England
# 5                            Chihuahua            Mexico
# 6                                Boxer           Germany
# 7                     Golden Retriever          Scotland
# 8                                  Pug             China
# 9                           Rottweiler           Germany
# 10                      Siberian Husky            Russia
# 11                           Dachshund           Germany
# 12                            Shih Tzu             China
# 13                        Bichon Frise            France
# 14                 Australian Shepherd         Australia
# ...

# %%
dogs=dogs.rename(columns={'Height (in)':'height','Longevity (yrs)':'longevity'})
dogs
# Out:
#                                  Breed Country of Origin  \
# 0                   Labrador Retriever            Canada
# 1                      German Shepherd           Germany
# 2                              Bulldog           England
# 3                               Poodle            France
# 4                               Beagle           England
# 5                            Chihuahua            Mexico
# 6                                Boxer           Germany
# 7                     Golden Retriever          Scotland
# 8                                  Pug             China
# 9                           Rottweiler           Germany
# 10                      Siberian Husky            Russia
# 11                           Dachshund           Germany
# 12                            Shih Tzu             China
# 13                        Bichon Frise            France
# 14                 Australian Shepherd         Australia
# ...

# %%
dogs.columns=dogs.columns.str.lower()

# %%
dogs
# Out:
#                                  breed country of origin  \
# 0                   Labrador Retriever            Canada
# 1                      German Shepherd           Germany
# 2                              Bulldog           England
# 3                               Poodle            France
# 4                               Beagle           England
# 5                            Chihuahua            Mexico
# 6                                Boxer           Germany
# 7                     Golden Retriever          Scotland
# 8                                  Pug             China
# 9                           Rottweiler           Germany
# 10                      Siberian Husky            Russia
# 11                           Dachshund           Germany
# 12                            Shih Tzu             China
# 13                        Bichon Frise            France
# 14                 Australian Shepherd         Australia
# ...

# %%
dogs[['trait1','trait2','trait3','trait4','trait5']]=dogs['character traits'].str.split(",",expand=True)

dogs
# Out:
#                                  breed country of origin  \
# 0                   Labrador Retriever            Canada
# 1                      German Shepherd           Germany
# 2                              Bulldog           England
# 3                               Poodle            France
# 4                               Beagle           England
# 5                            Chihuahua            Mexico
# 6                                Boxer           Germany
# 7                     Golden Retriever          Scotland
# 8                                  Pug             China
# 9                           Rottweiler           Germany
# 10                      Siberian Husky            Russia
# 11                           Dachshund           Germany
# 12                            Shih Tzu             China
# 13                        Bichon Frise            France
# 14                 Australian Shepherd         Australia
# ...

# %%
dogs['fur color'].str.split(",",expand=True)
# Out:
#                  0               1           2           3
# 0           Yellow           Black   Chocolate        None
# 1            Black             Tan        None        None
# 2            White             Red        None        None
# 3            White           Black       Brown     Apricot
# 4            White             Tan         Red       Lemon
# 5            Black           Brown         Tan       White
# 6             Fawn         Brindle        None        None
# 7           Golden            None        None        None
# 8             Fawn           Black        None        None
# 9            Black             Tan        None        None
# 10           Black           White        None        None
# 11           Black             Tan        None        None
# 12           Black           White       Brown        None
# 13           White            None        None        None
# 14           Black             Red        None        None
# ...

# %%
dogs['breed'].count()

# %%
traits=['loyal','calm']

# %%
dogs[dogs['character traits'].isin(traits)]
# this wont run cuz contains command cant be used to run a list

# %% [markdown]
# #####  Parker needs a dog thats intelligent, loyal, color doesnt matter

# %%
intelligent=dogs[dogs['character traits'].str.contains('intelligent')]
intelligent

# %%
intelligent.count()

# %%
parker=intelligent[intelligent['character traits'].str.contains('loyal')]
parker

# %%
parker.count()

# %% [markdown]
# ### Mr Walker needs a dog for security of his farm ,desired traits: energetic ,protective and color brown with longetivity of 7-10yrs

# %%
protective=dogs[dogs['character traits'].str.contains('protective')]
protective

# %%
walker=protective[protective['character traits'].str.contains('loyal')]
walker

# %%
protective.count()

# %%
fur_color=dogs['fur color'].count()

# %%
### number of black dogs,brown and white dogs

# %%
black=dogs[dogs['fur color'].str.contains('Black')]
black

# %%
black.count()

# %%
black['breed']

# %%
white=dogs[dogs['fur color']=='White']
white

# %%
white.count()

# %%
brown=dogs[dogs['fur color']=='Brown']
brown

# %%
dogs[dogs['fur color'].str.contains('Brown')]

# %%
dogs[dogs['fur color'].str.contains('Brown')].count()
